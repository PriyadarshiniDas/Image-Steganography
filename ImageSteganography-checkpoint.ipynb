# %%
#Red channel Two Least Significant bits and Green channel Two Least Significant bits
import numpy as np
import cv2
#from matplotlib import pyplot as plt
import random 
import math

img=cv2.imread('baby512.png')
cv2.imshow('OriginalImage',img)
fg1=img.copy()
fg2=img.copy()

file = open("msg.txt","r")
msgDetail=file.read()

#Text message to binary bit conversion
#print(msgDetail)
list=[]
for i in (msgDetail):
    binary_msg='{0:08b}'.format(ord(i))
    list.append(binary_msg)
        
#print('List=',list)
list_new=[]
for i in range (len(list)):
    for j in range (8):
        list_new.append(list[i][j])
    #print('New List=',(list_new))
    
desired_array = [int(list_new) for list_new in list_new]
Message_Length=len(desired_array)
#print('Integer List=',desired_array)
        
#return desired_array

def encode_msg():
    #print(msgDetail)
    
    row_counter=0
    col_counter=0
    
    #Convert text message to binary digit
    for i in range (0,len(desired_array),4):
        R=fg1[row_counter,col_counter,0]
        G=fg1[row_counter,col_counter,1]
        #B=fg1[row_counter,col_counter,2]
        #print('Value of R=', R)   
        #print('Value of G=', G)
        #print('Value of B=', B)
        R_binary='{0:08b}'.format((R))
        G_binary='{0:08b}'.format((G))
        #B_binary='{0:08b}'.format((B))
        #print('Binary value of R=',R_binary)
        #print('Binary value of G=',G_binary)
        #print('Binary value of B=',B_binary)
        int_R = [int(R_binary) for R_binary in R_binary]
        int_G = [int(G_binary) for G_binary in G_binary]
        #print('Integer R', int_R)
        #print('Integer G', int_G)
        int_R[7]=desired_array[i] 
        int_R[6]=desired_array[i+1]
        int_G[7]=desired_array[i+2]
        int_G[6]=desired_array[i+3]
        decimal_val_R=(128*int_R[0])+(64*int_R[1])+(32*int_R[2])+(16*int_R[3])+(8*int_R[4])+(4*int_R[5])+(2*int_R[6])+(1*int_R[7])
        decimal_val_G=(128*int_G[0])+(64*int_G[1])+(32*int_G[2])+(16*int_G[3])+(8*int_G[4])+(4*int_G[5])+(2*int_G[6])+(1*int_G[7])
        #print('VALUE',decimal_val_R)
        #print('VALUE',decimal_val_G)
        fg2[row_counter,col_counter,0]=decimal_val_R
        fg2[row_counter,col_counter,1]=decimal_val_G
        #print('Print intR after replacement=', int_R)
        #print('Print intR[7] after replacement=',int_R[7])
        #print('Print intG after replacement=', int_G)
        #print('Print intG[7] after replacement=',int_G[7])
        col_counter=col_counter+1
        if(col_counter > fg1.shape[1]-1):
            col_counter=0
            row_counter=row_counter+1
        if(row_counter > fg1.shape[0]-1):
            break
            
            
    encoded_msg=fg2.copy()
    
    #for row in range(0,encoded_msg.shape[0]):  #traverse rows of matrix
        #for col in range(0,encoded_msg.shape[1]):
            #R_decode=encoded_msg[row,col,0]
            #R_binary='{0:08b}'.format((R_decode))
            #print('R_Binary=',R_binary)
    cv2.imwrite('EncodedImage.png',encoded_msg)
    cv2.imshow('Encoded message Image',encoded_msg)
    cv2.waitKey(0)
                    
    return encoded_msg
    
                
def decode_msg():
    print('---------START DECODING------------')
    encoded_msg=cv2.imread('EncodedImage.png')
    list_decode=[]
    for row in range(0,encoded_msg.shape[0]):  #traverse rows of matrix
        for col in range(0,encoded_msg.shape[1]):
            R_decode=encoded_msg[row,col,0]
            G_decode=encoded_msg[row,col,1]
            R_binary='{0:08b}'.format((R_decode))
            G_binary='{0:08b}'.format((G_decode))
            #print('R_Binary=',R_binary)
            #print('G_Binary=',G_binary)
            R_LSB1=R_binary[7]
            R_LSB2=R_binary[6]
            G_LSB1=G_binary[7]
            G_LSB2=G_binary[6]
            #print('R_LSB value=',R_LSB)
            list_decode.append(R_LSB1)
            list_decode.append(R_LSB2)
            list_decode.append(G_LSB1)
            list_decode.append(G_LSB2)
            #print('XYZ')
            #print('Decoded msg string=',list_decode)
            DecodedMessage_Length=len(list_decode)
            #print(DecodedMessage_Length)
            #print(Message_Length)
            #int_DecodedMessage = [int(list_decode) for list_decode in list_decode]
            #print('Integer R', int_R)
            if DecodedMessage_Length>=Message_Length:
                break
        if DecodedMessage_Length>=Message_Length:
            break
    int_DecodedMessage = [int(list_decode) for list_decode in list_decode]
    #print('DecodedMessage =', int_DecodedMessage)
    Message=" "
    for i in range (0,DecodedMessage_Length,8):
        decimal_val_msg=(128*int_DecodedMessage[i])+(64*int_DecodedMessage[i+1])+(32*int_DecodedMessage[i+2])+(16*int_DecodedMessage[i+3])+(8*int_DecodedMessage[i+4])+(4*int_DecodedMessage[i+5])+(2*int_DecodedMessage[i+6])+(1*int_DecodedMessage[i+7])
        #print('Decimal value=',decimal_val_msg)
        character=chr(decimal_val_msg)
        #print('Character=',character)
        #Message.append(character)
        Message+=character
    print(Message)
        
    #return decoded_msg
def main():
    #binary_msg=msg_to_bit_generator(msgDetail)
    encoded_msg=encode_msg()
    decoded_msg=decode_msg()
main()
# Out:
# ---------START DECODING------------
#  MEIN KAMPF
# HURST AND BLACKETT LTD.,
# Publishers since 1812
# LONDON  NEW YORK  MELBOURNE
# This translation of the unexpurgated edition of "Mein Kampf"
# was first published on March 21st, 1939
# FOOT NOTES.......................................................................................................3
# VOLUME I: A RETROSPECT............................................................................7
# INTRODUCTION - AUTHORS PREFACE..................................................7
# TRANSLATORS INTRODUCTION..............................................................9
# EXCERPTS.....................................................................................................14
# CHAPTER I: IN THE HOME OF MY PARENTS........................................17
# CHAPTER II: YEARS OF STUDY AND SUFFERING IN VIENNA.........28
# ...
